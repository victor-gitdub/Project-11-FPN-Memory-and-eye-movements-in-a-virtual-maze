# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pathlib import Path

# %%
# learning rate
df = pd.read_csv("processed_data\participant_summary.csv")
learning_rate = df[["Participant_ID","Pct_Improvement"]]

# distance to target mean
mean_dist = {}

for file in Path(".").glob("*_SESSION2.csv"):
    dfs = pd.read_csv(file)
    participant = file.stem.split("_")[0]
    distance = dfs['distance_to_target'].mean()
    mean_dist[participant] = distance

DataFrame = pd.DataFrame(list(mean_dist.items()),columns=["Participant_ID","distance_to_target"])
complete = pd.merge(learning_rate, DataFrame, on="Participant_ID")
print(complete)
# Out:
#    Participant_ID  Pct_Improvement  distance_to_target
# 0           PID18            74.52            3.416149
# 1           PID14            67.83            4.868748
# 2           PID15            67.56            2.863790
# 3           PID28            56.49            3.063297
# 4           PID26            53.02            6.771199
# 5           PID29            48.33            6.894211
# 6           PID11            48.08            4.291922
# 7           PID22            47.85           11.809069
# 8           PID17            46.69            6.420144
# 9           PID16            43.84            9.167167
# 10          PID27            42.89            7.133076
# 11          PID25            41.91            3.658506
# 12          PID19            28.53            2.949495
# 13          PID20            26.61            4.289345
# 14          PID23            25.45            5.828611
# 15          PID10            23.50            4.355225
# 16          PID12             3.48            5.091050
# 17          PID24            -3.48            5.897190
# 18          PID21           -35.05            7.951892
# 19          PID13          -151.42            9.007261
